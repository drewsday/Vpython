# %%
import IPython
print IPython.sys_info()
# Out:
# {'commit_hash': '681fd77',
#  'commit_source': 'installation',
#  'default_encoding': 'UTF-8',
#  'ipython_path': '/Library/Frameworks/Python.framework/Versions/7.3/lib/python2.7/site-packages/IPython',
#  'ipython_version': '2.1.0',
#  'os_name': 'posix',
#  'platform': 'Darwin-13.1.0-x86_64-i386-32bit',
#  'sys_executable': '/Library/Frameworks/Python.framework/Versions/7.3/Resources/Python.app/Contents/MacOS/Python',
#  'sys_platform': 'darwin',
#  'sys_version': '2.7.3 |EPD_free 7.3-2 (32-bit)| (default, Apr 12 2012, 11:28:34) \n[GCC 4.0.1 (Apple Inc. build 5493)]'}

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.linspace(0, 3*np.pi, 500)
plt.plot(x, np.sin(x**2))
plt.title('A simple chirp');

# %%
from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt, mpld3
import numpy as np
from matplotlib import cm
from bokeh.plotting import *

#output_file("rect.html", title="rect-membrane-noloop.py example")

pi = np.pi

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
#X, Y, Z = axes3d.get_test_data(0.05)

#set up lengths of the sides
Lx = 1
Ly = 2

x = np.linspace(0,Lx,50)
y = np.linspace(0,Ly,50)

X,Y = np.meshgrid(x,y)

#print X

#set up mode numbers
nx = 2
ny = 2
#for nx in range(5):
#    for ny in range(5):
#set up wave numbers
kx = nx*pi / Lx
ky = ny*pi / Ly


print type(x)
#print np.shape(x)
#        print type(y)
#        print np.shape(y)
#Z = np.dot( np.sin(kx*x), np.sin(ky*y))
Z = np.sin(kx*X) * np.sin(ky*Y)

#print type(Z)
#print np.shape(Z)

#ax.plot_wireframe(X, Y, Z, rstride=4, cstride=4)
ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap=cm.coolwarm, linewidth=0, antialiased=True)
#ax.plot_surface(x, y, Z)

#fig = plt.figure()
#ax = fig.gca(projection='3d')

#ax.plot_trisurf(X, Y, Z, cmap=cm.jet, linewidth=0.2)

ax.view_init(elev=30., azim=30.)
plt.axis('off')
#plt.show()
#mpld3.save_html(plt,"out.html")
#mpld3.show()
#plt.savefig("rect-membrane{0}{1}.png".format(nx,ny))
# Out:
# <type 'numpy.ndarray'>
# (0.0, 1.0, 0.0, 2.0)
